# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimberly-dsouza/data-mining/blob/master/illness_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("new_data7.csv")

# %%
data.head()
# Out:
#          state  state_code  ...  state_code_23  breast_feeding_months
# 0  Uttaranchal           5  ...              0                    4.0
# 1  Uttaranchal           5  ...              0                    2.0
# 2  Uttaranchal           5  ...              0                    4.0
# 3  Uttaranchal           5  ...              0                    1.0
# 4  Uttaranchal           5  ...              0                    3.0
#
# [5 rows x 48 columns]

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['state', 'state_code', 'rural_urban', 'record_code_iodine', 'sex',
#        'age', 'weight_in_kg', 'length_height_cm', 'haemoglobin_level',
#        'first_breast_feeding', 'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'illness_duration', 'treatment_type', 'male',
#        'treatment_hospital', 'first_breast_feeding_1.0',
#        'first_breast_feeding_2.0', 'first_breast_feeding_3.0',
#        'first_breast_feeding_4.0', 'first_breast_feeding_5.0', 'rural',
#        'iodine_PPM__1', 'iodine_PPM__2', 'iodine_PPM__3', 'state_code_5',
#        'state_code_8', 'state_code_9', 'state_code_10', 'state_code_20',
#        'state_code_21', 'state_code_22', 'state_code_23',
#        'breast_feeding_months'],
#       dtype='object')

# %%
cols=

# %%
# %matplotlib inline
#matplot.lib for plotting 
import matplotlib.pyplot as plt
plt.style.use(style = 'default')
plt.title("age", fontsize=14)
data['age'].hist(figsize=(5,5))

# %%
h = sns.factorplot(x = 'state', hue='rural_urban', kind ='count', size = 5,aspect=1.5, data=data, palette='Set1' )
plt.title("Statewise rural urban", fontsize=14)
plt.xticks(rotation=45)
#h.set_xticklabels(['High', 'Medium', 'Low'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %%
h = sns.factorplot(x = 'illness_type', hue='treatment_hospital', kind ='count', size = 5,aspect=1.5, data=data )
plt.title("Treatment at hospital", fontsize=14)
plt.xticks(rotation=45)
h.set_xticklabels(['None','Diarrhoea', 'Acute Respiratory Infection', 'Fever', 'Other'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
pivot_df = data.pivot(index='Year', columns='Month', values='Value')
pivot_df

# %%
# Number of days/months was the child exclusively  breastfed

cols=['water_month','ani_milk_month','semisolid_month_or_day','solid_month','vegetables_month_or_day','breast_feeding_months']
f, ax = plt.subplots(ncols = 2, nrows = 3)

for i, c in zip(ax.flatten(), cols):
    sns.distplot(data[c], ax = i)

f.tight_layout()


#sns.distplot(data['breast_feeding_months'], hist = False, kde = True,
#                kde_kws = {'shade': True, 'linewidth': 3})

# %%
# haemoglobin level distribution

sns.distplot(data['haemoglobin_level'], hist = False, kde = True,
              kde_kws = {'shade': True, 'linewidth': 3})

# %%
sns.barplot(x=round(data['age']),y=data['weight_in_kg'])
plt.title("Age vs Weight")
# Out:
# Text(0.5, 1.0, 'Age vs Weight')

# %%
sns.barplot(x=round(data['age']),y=data['length_height_cm'])
plt.title("Age vs Height")
# Out:
# Text(0.5, 1.0, 'Age vs Height')

# %%
# First breast fed count

h = sns.factorplot(x = 'first_breast_feeding', kind ='count', size = 5,aspect=1.5, data=data )
plt.title("When was the child first breast fed", fontsize=14)
plt.xticks(rotation=45)
h.set_xticklabels(['1 hr', '1-24 hrs', '2-3 days', 'after 3 days', 'never'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Recorded iodine content

h = sns.factorplot(x = 'record_code_iodine', kind ='count', size = 5,aspect=1.5, data=data )
plt.title("Iodine content", fontsize=14)
plt.xticks(rotation=45)
h.set_xticklabels(['None', '<15 PPM', '>= 15 PPM', 'No salt in house', 'salt not tested'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# statewise distribution of illnesses 

h = sns.factorplot(x = 'state', hue='illness_type', kind ='count', size = 5,aspect=1.5, data=data, palette='Set1' )
plt.title("statewise distribution of illnesses", fontsize=14)
plt.xticks(rotation=45)

new_labels = ['No illness', 'Diarrhoea','Acute Respiratory Infection','Fever','Other']
for t, l in zip(h._legend.texts, new_labels): t.set_text(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# duration of illness in days
plt.title("duration of illness in days", fontsize=14)

sns.distplot(data['illness_duration'], hist = False, kde = True,
              kde_kws = {'shade': True, 'linewidth': 3})

# %%
# illness and duration
plt.title("illness duration", fontsize=14)
h=sns.barplot(x='illness_type',y='illness_duration',data=data)
h.set_xticklabels(['None','Diarrhoea', 'Acute Respiratory Infection', 'Fever', 'Other'])
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
data.columns
# Out:
# Index(['state', 'state_code', 'rural_urban', 'record_code_iodine', 'sex',
#        'age', 'weight_in_kg', 'length_height_cm', 'haemoglobin_level',
#        'first_breast_feeding', 'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'illness_duration', 'treatment_type', 'male',
#        'treatment_hospital', 'first_breast_feeding_1.0',
#        'first_breast_feeding_2.0', 'first_breast_feeding_3.0',
#        'first_breast_feeding_4.0', 'first_breast_feeding_5.0', 'rural',
#        'iodine_PPM__1', 'iodine_PPM__2', 'iodine_PPM__3', 'state_code_5',
#        'state_code_8', 'state_code_9', 'state_code_10', 'state_code_20',
#        'state_code_21', 'state_code_22', 'state_code_23',
#        'breast_feeding_months'],
#       dtype='object')

# %%
temp_df=data[data['treatment_hospital']==1]

# %%
# statewise distribution of illnesses 

h = sns.factorplot(x = 'illness_type', kind ='count', size = 5,aspect=1.5, data=temp_df, palette='Set1' )
plt.title("hospitalized for the specific acute illness during last 15 days", fontsize=14)
h.set_xticklabels(['Diarrhoea', 'Acute Respiratory Infection', 'Fever', 'Other'])

plt.xticks(rotation=45)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
data.columns
# Out:
# Index(['state', 'state_code', 'rural_urban', 'record_code_iodine', 'sex',
#        'age', 'weight_in_kg', 'length_height_cm', 'haemoglobin_level',
#        'first_breast_feeding', 'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'illness_duration', 'treatment_type', 'male',
#        'treatment_hospital', 'first_breast_feeding_1.0',
#        'first_breast_feeding_2.0', 'first_breast_feeding_3.0',
#        'first_breast_feeding_4.0', 'first_breast_feeding_5.0', 'rural',
#        'iodine_PPM__1', 'iodine_PPM__2', 'iodine_PPM__3', 'state_code_5',
#        'state_code_8', 'state_code_9', 'state_code_10', 'state_code_20',
#        'state_code_21', 'state_code_22', 'state_code_23',
#        'breast_feeding_months'],
#       dtype='object')

# %%
temp = data[data['solid_month']>=1]

# %%
final_cols=['age',
       'weight_in_kg', 'length_height_cm', 'haemoglobin_level', 'water_month', 'ani_milk_month',
       'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day', 'illness_duration', 'male',
       'treatment_hospital', 'first_breast_feeding_1.0',
       'first_breast_feeding_2.0', 'first_breast_feeding_3.0',
       'first_breast_feeding_4.0', 'first_breast_feeding_5.0', 'rural',
       'iodine_PPM__1', 'iodine_PPM__2', 'iodine_PPM__3', 'state_code_5',
       'state_code_8', 'state_code_9', 'state_code_10', 'state_code_20',
       'state_code_21', 'state_code_22', 'state_code_23',
       'breast_feeding_months']

target_col='illness_type'

from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(data[final_cols], data[target_col], test_size=0.3)
X_train, X_test, y_train, y_test = train_test_split(temp[final_cols], temp[target_col], test_size=0.3)

# %%
temp[final_cols].shape
# Out:
# (23611, 30)

# %%
# Running Multinomial Regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(multi_class='multinomial',solver='newton-cg', penalty='l2')
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='multinomial', n_jobs=None,
#                    penalty='l2', random_state=None, solver='newton-cg',
#                    tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=lr.predict(X_test)
lr.score(X_test,y_test)
# Out:
# 0.5876623376623377

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1163,    2,   81,    0,    0],
#        [  24,  557,  706,  215,    1],
#        [  23,  378, 2230,  300,    4],
#        [  37,  195,  491,  445,    3],
#        [   0,   53,   97,   77,    2]])

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
#Running random forest
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=200, min_samples_split=30)
clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)
clf.score(X_test, y_test)
# Out:
# 0.6816770186335404

# %%
feature_imp=pd.Series(clf.feature_importances_, index=final_cols).sort_values(ascending=False)

# %%
feature_imp
# Out:
# illness_duration            0.178103
# solid_month                 0.082897
# length_height_cm            0.080525
# weight_in_kg                0.075045
# vegetables_month_or_day     0.073005
# ani_milk_month              0.062760
# breast_feeding_months       0.060216
# semisolid_month_or_day      0.058816
# haemoglobin_level           0.055439
# water_month                 0.049774
# age                         0.029547
# state_code_20               0.022259
# first_breast_feeding_1.0    0.018155
# male                        0.017307
# first_breast_feeding_2.0    0.016220
# state_code_10               0.015522
# state_code_8                0.013420
# rural                       0.010412
# state_code_21               0.010249
# state_code_9                0.009926
# state_code_23               0.009323
# treatment_hospital          0.008965
# iodine_PPM__3               0.008375
# iodine_PPM__2               0.007318
# state_code_5                0.007292
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.model_selection import RandomizedSearchCV
rs = RandomizedSearchCV(RandomForestClassifier(max_depth=20),
                  {
                      'n_estimators':[10,100,200],
                      'min_samples_split':[50,60,30]
                  }, 
                  cv=3, return_train_score=False)

# %%
rs.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=20,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
# ...

# %%
rs.best_score_
# Out:
# 0.6754401887819931

# %%
rs.best_params_
# Out:
# {'min_samples_split': 30, 'n_estimators': 200}

# %%
# Running decision tree classifier
# Tried criterion = 'entropy'

from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier(criterion='entropy', min_samples_split=30, max_depth=8)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
clf.score(X_test,y_test)
# Out:
# 0.6596555618294748

# %%
#Running KNN

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)
from sklearn.neighbors import KNeighborsClassifier

# %%
error=[]
for i in range(1,41):
    knn=KNeighborsClassifier(n_neighbors=1)
    knn.fit(X_train, y_train)
    pred_i=knn.predict(X_test)
    error.append(np.mean(pred_i!=y_test))
    

plt.figure(figsize=(12,6))
plt.plot(range(1,41),error, color='red', linestyle='dashed', marker='o', markerfacecolor='blue', markersize=10)
print(sorted(error))
# Out:
# [0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245, 0.42504234895539245]

# %%
classifier=KNeighborsClassifier(n_neighbors=10)
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)

# %%
classifier.score(X_test, y_test)
# Out:
# 0.6012140033879164

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1035   95   79   37    0]
#  [ 113  760  406  224    0]
#  [ 147  534 2019  230    5]
#  [ 138  313  274  441    5]
#  [  17   67   85   56    4]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77      1246
#            1       0.43      0.51      0.46      1503
#            2       0.71      0.69      0.70      2935
#            3       0.45      0.38      0.41      1171
#            4       0.29      0.02      0.03       229
#
#     accuracy                           0.60      7084
#    macro avg       0.52      0.48      0.47      7084
# weighted avg       0.59      0.60      0.59      7084

# %%
# Running SVC



from sklearn import svm

# %%
#manually tune hyper parameters

# 1. use train test split
model = svm.SVC(kernel = 'rbf', C=30, gamma='auto')
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.609966120835686

# %%
from sklearn.model_selection import RandomizedSearchCV
rs = RandomizedSearchCV(svm.SVC(gamma='auto'),
                  {
                      'C':[1,10,20],
                      'kernel':['rbf','linear']
                  }, 
                  cv=5, return_train_score=False, n_iter=2)

# %%
rs.fit(X_train, y_train)
